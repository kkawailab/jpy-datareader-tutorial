# %% [markdown]
# # 第5章: データ分析の実践## 📚 この章で学ぶこと- 時系列分析- 地域比較分析- データ可視化

# %% [markdown]
# ## 5.1 環境準備

# %%
import pandas as pdimport matplotlib.pyplot as pltfrom jpy_datareader.estat import StatsDataReaderfrom dotenv import load_dotenvload_dotenv()# 日本語フォント設定（環境に応じて調整）plt.rcParams['font.sans-serif'] = ['DejaVu Sans']plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# ## 5.2 時系列分析の基本

# %%
# データを取得reader = StatsDataReader()stats_id = "0003410379"df = reader.read(statsDataId=stats_id, limit=500)print(f"データ取得: {len(df)}件")df.head()

# %% [markdown]
# ## 5.3 データの可視化

# %%
# 数値データの基本統計量numeric_cols = df.select_dtypes(include=['float64', 'int64']).columnsif len(numeric_cols) > 0:    print("数値カラム:", list(numeric_cols))    df[numeric_cols].describe()

# %% [markdown]
# ## 📝 練習問題### 問題1: データを可視化してみましょう

# %%
# 問題1: 数値データのヒストグラムを描画してください

# %% [markdown]
# ## 🎯 まとめ**[第6章へ進む](./chapter06_best_practices.ipynb)**

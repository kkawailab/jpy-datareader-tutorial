# %% [markdown]
# # 第4章: StatsDataReaderでデータを取得## 📚 この章で学ぶこと- StatsDataReaderの使い方- フィルタリング機能- 大量データの取得

# %% [markdown]
# ## 4.1 StatsDataReaderの基本

# %%
from jpy_datareader.estat import StatsDataReaderfrom dotenv import load_dotenvload_dotenv()reader = StatsDataReader()stats_id = "0003410379"

# %% [markdown]
# ## 4.2 データの取得

# %%
# データを取得df = reader.read(statsDataId=stats_id, limit=100)print(f"取得データ: {len(df)}行 × {len(df.columns)}列")df.head()

# %% [markdown]
# ## 4.3 地域フィルタリングメタ情報から地域コードを取得してフィルタリングできます。

# %%
# 地域でフィルタリングする場合の例# from jpy_datareader.estat import MetaInfoReader# meta_reader = MetaInfoReader()# df_meta = meta_reader.read(statsDataId=stats_id)# ... 地域コードを検索してcdAreaに指定

# %% [markdown]
# ## 📝 練習問題### 問題1: 1000件のデータを取得してみましょう

# %%
# 問題1: limit=1000でデータを取得してください

# %% [markdown]
# ## 🎯 まとめ**[第5章へ進む](./chapter05_advanced_analysis.ipynb)**

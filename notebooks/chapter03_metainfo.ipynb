# %% [markdown]
# # 第3章: MetaInfoReaderでメタ情報を取得## 📚 この章で学ぶこと- MetaInfoReaderの使い方- データ構造の理解- 分類階層の取得

# %% [markdown]
# ## 3.1 MetaInfoReaderの基本

# %%
from jpy_datareader.estat import MetaInfoReaderfrom dotenv import load_dotenvload_dotenv()reader = MetaInfoReader()stats_id = "0003410379"

# %% [markdown]
# ## 3.2 メタ情報の取得

# %%
# メタ情報を取得df_meta = reader.read(statsDataId=stats_id)print(f"メタ情報: {len(df_meta)}件")df_meta.head()

# %% [markdown]
# ## 3.3 分類の確認

# %%
# 分類の種類を確認if '@class' in df_meta.columns:    print("【分類の種類】")    for cls in df_meta['@class'].unique():        count = len(df_meta[df_meta['@class'] == cls])        print(f"  {cls}: {count}件")

# %% [markdown]
# ## 📝 練習問題### 問題1: 地域分類を抽出してみましょう

# %%
# 問題1: '@class'が'area'のデータを抽出してください

# %% [markdown]
# ## 🎯 まとめ**[第4章へ進む](./chapter04_statsdata.ipynb)**

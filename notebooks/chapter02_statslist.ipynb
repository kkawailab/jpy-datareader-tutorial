# %% [markdown]
# # 第2章: StatsListReaderで統計表を探す## 📚 この章で学ぶこと- StatsListReaderクラスの詳細- 高度な検索テクニック- フィルタリングとソート

# %% [markdown]
# ## 2.1 StatsListReaderの基本

# %%
from jpy_datareader.estat import StatsListReaderfrom dotenv import load_dotenvload_dotenv()# StatsListReaderのインスタンスを作成reader = StatsListReader()print("✅ StatsListReaderを初期化しました")

# %% [markdown]
# ## 2.2 基本的な検索

# %%
# キーワード検索df = reader.read(searchWord="人口", limit=10)print(f"検索結果: {len(df)}件")df[['@id', 'STAT_NAME', 'TITLE']].head()

# %% [markdown]
# ## 2.3 検索方法の指定- searchKind=1: AND検索- searchKind=2: OR検索

# %%
# AND検索の例df_and = reader.read(searchWord="人口 推計", searchKind=1, limit=5)print(f"AND検索結果: {len(df_and)}件")df_and[['TITLE']].head()

# %% [markdown]
# ## 📝 練習問題### 問題1: OR検索を試してみましょう

# %%
# 問題1: 「GDP」または「経済」で検索してください

# %% [markdown]
# ## 🎯 まとめこの章では以下を学びました：- StatsListReaderの使い方- 検索方法の指定**[第3章へ進む](./chapter03_metainfo.ipynb)**
